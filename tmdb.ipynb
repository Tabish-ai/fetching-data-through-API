# %%
import pandas as pd
import requests

# %%
##requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwN2Q5M2FiMTNiNjVhNTdmNTdlOTg4M2IxYjhiYzYwZSIsIm5iZiI6MTc1NjMxODQ5NS43MDU5OTk5LCJzdWIiOiI2OGFmNGIxZjE2M2EzMDFkZDI1NmJhZTYiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.iaNZw4pMdzMqQakz6b7I52VzBAPg7zugl155WxwRsIM&language=en-US&page=1')

# %%
response = requests.get('http://api.openweathermap.org/data/2.5/forecast?q=London&appid=e02a46e79b3a357884420ee09532a7e4')

# %%
data = response.json()
data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1756339200,
#    'main': {'temp': 289.3,
#     'feels_like': 289.19,
#     'temp_min': 289.3,
#     'temp_max': 289.3,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 999,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.2, 'deg': 228, 'gust': 4.7},
#    'visibility': 10000,
#    'pop': 0.8,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-08-28 00:00:00'},
#   {'dt': 1756350000,
#    'main': {'temp': 288.84,
#     'feels_like': 288.68,
#     'temp_min': 287.93,
#     'temp_max': 288.84,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 999,
#     'humidity': 85,
#     'temp_kf': 0.91},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
# ...

# %%
forecast = data['list']
city_info = data['city']

# %%
forecast
# Out:
# [{'dt': 1756339200,
#   'main': {'temp': 289.3,
#    'feels_like': 289.19,
#    'temp_min': 289.3,
#    'temp_max': 289.3,
#    'pressure': 1003,
#    'sea_level': 1003,
#    'grnd_level': 999,
#    'humidity': 85,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.2, 'deg': 228, 'gust': 4.7},
#   'visibility': 10000,
#   'pop': 0.8,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-08-28 00:00:00'},
#  {'dt': 1756350000,
#   'main': {'temp': 288.84,
#    'feels_like': 288.68,
#    'temp_min': 287.93,
#    'temp_max': 288.84,
#    'pressure': 1003,
#    'sea_level': 1003,
#    'grnd_level': 999,
#    'humidity': 85,
#    'temp_kf': 0.91},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 83},
#   'wind': {'speed': 1.77, 'deg': 236, 'gust': 3.99},
#   'visibility': 10000,
# ...

# %%
df_forecast= pd.json_normalize(forecast)

# %%
df_forecast.head(2)
# Out:
#            dt                                            weather  visibility  \
# 0  1756339200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 1  1756350000  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
#
#    pop               dt_txt  main.temp  main.feels_like  main.temp_min  \
# 0  0.8  2025-08-28 00:00:00     289.30           289.19         289.30
# 1  0.0  2025-08-28 03:00:00     288.84           288.68         287.93
#
#    main.temp_max  main.pressure  main.sea_level  main.grnd_level  \
# 0         289.30           1003            1003              999
# 1         288.84           1003            1003              999
#
#    main.humidity  main.temp_kf  clouds.all  wind.speed  wind.deg  wind.gust  \
# 0             85          0.00         100        2.20       228       4.70
# 1             85          0.91          83        1.77       236       3.99
#
#   sys.pod  rain.3h
# 0       n      NaN
# 1       n      NaN

# %%
df_forecast['city']= city_info['name']
df_forecast['country']=city_info['country']

# %%
df_forecast.head(2)
# Out:
#            dt                                            weather  visibility  \
# 0  1756339200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 1  1756350000  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
#
#    pop               dt_txt  main.temp  main.feels_like  main.temp_min  \
# 0  0.8  2025-08-28 00:00:00     289.30           289.19         289.30
# 1  0.0  2025-08-28 03:00:00     288.84           288.68         287.93
#
#    main.temp_max  main.pressure  ...  main.humidity  main.temp_kf  clouds.all  \
# 0         289.30           1003  ...             85          0.00         100
# 1         288.84           1003  ...             85          0.91          83
#
#    wind.speed  wind.deg  wind.gust  sys.pod  rain.3h    city  country
# 0        2.20       228       4.70        n      NaN  London       GB
# 1        1.77       236       3.99        n      NaN  London       GB
#
# [2 rows x 22 columns]
